# %%
import pandas as pd
import plotly.offline as pyo
import plotly.graph_objects as go

# %%
df = pd.read_pickle('../Data/data.pkl')

# %%
df.head()
# Out:
#                 Verwendungszweck  Zusageobligo  SDG 1  1.1  1.2  1.3  1.4  \
# 0               Abfallvermeidung  1.834510e+07    NaN  NaN  NaN  NaN  NaN
# 1            Abfallvorbehandlung  5.874000e+06    NaN  NaN  NaN  NaN  NaN
# 2               Abfallwirtschaft  3.824088e+06    NaN  NaN  NaN  NaN  NaN
# 3  Abluftanlage gem. Prog.Merkb.  4.493885e+06    NaN  NaN  NaN  NaN  NaN
# 4             Abwasserentsorgung  3.065568e+08    NaN  NaN  NaN  NaN  NaN
#
#    1.5  1.A  1.B  ...  17.10  17.11  17.12  17.13  17.14  17.15  17.16  17.17  \
# 0  NaN  NaN  NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1  NaN  NaN  NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2  NaN  NaN  NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3  NaN  NaN  NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4  NaN  NaN  NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#    17.18  17.19
# 0    NaN    NaN
# 1    NaN    NaN
# ...

# %%
data = [go.Scatter(
        x = df['Verwendungszweck'],
        y = df['Zusageobligo'],
        mode = 'lines',
        name = 'Zusageobligo'
        )] 

layout = go.Layout(title = 'Zusageobligo pro Verwendungszweck')

fig = go.Figure(data=data, layout=layout)

pyo.plot(fig, filename='Zusageobligo pro Verwendungszweck.html')
# Out:
# 'Zusageobligo pro Verwendungszweck.html'
